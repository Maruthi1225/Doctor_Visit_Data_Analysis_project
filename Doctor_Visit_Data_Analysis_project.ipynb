# %%
# Doctor Visit Data Analysis project IBM skill Build intership

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dvd=pd.read_csv("Doctor_Visits_dataset.csv")
print(dvd.head())
# Out:
#    Unnamed: 0  visits  gender   age  income  illness  reduced  health private  \
# 0           1       1  female  0.19    0.55        1        4       1     yes
# 1           2       1  female  0.19    0.45        1        2       1     yes
# 2           3       1    male  0.19    0.90        3        0       0      no
# 3           4       1    male  0.19    0.15        1        0       0      no
# 4           5       1    male  0.19    0.45        2        5       1      no
#
#   freepoor freerepat nchronic lchronic
# 0       no        no       no       no
# 1       no        no       no       no
# 2       no        no       no       no
# 3       no        no       no       no
# 4       no        no      yes       no

# %%
dvd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5190 non-null   int64
#  1   visits      5190 non-null   int64
#  2   gender      5190 non-null   object
#  3   age         5190 non-null   float64
#  4   income      5190 non-null   float64
#  5   illness     5190 non-null   int64
#  6   reduced     5190 non-null   int64
#  7   health      5190 non-null   int64
#  8   private     5190 non-null   object
#  9   freepoor    5190 non-null   object
#  10  freerepat   5190 non-null   object
#  11  nchronic    5190 non-null   object
#  12  lchronic    5190 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 527.2+ KB

# %%
dvd.head()
# Out:
#    Unnamed: 0  visits  gender   age  income  illness  reduced  health private  \
# 0           1       1  female  0.19    0.55        1        4       1     yes
# 1           2       1  female  0.19    0.45        1        2       1     yes
# 2           3       1    male  0.19    0.90        3        0       0      no
# 3           4       1    male  0.19    0.15        1        0       0      no
# 4           5       1    male  0.19    0.45        2        5       1      no
#
#   freepoor freerepat nchronic lchronic
# 0       no        no       no       no
# 1       no        no       no       no
# 2       no        no       no       no
# 3       no        no       no       no
# 4       no        no      yes       no
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# ...

# %%
dvd["reduced"].value_counts()
# Out:
# 0     4454
# 14     188
# 1      177
# 2      108
# 3       74
# 4       45
# 5       40
# 7       38
# 6       17
# 8       17
# 10      12
# 9        7
# 12       6
# 13       5
# 11       2
# Name: reduced, dtype: int64

# %%
dvd["illness"].value_counts()
# Out:
# 1    1638
# 0    1554
# 2     946
# 3     542
# 4     274
# 5     236
# Name: illness, dtype: int64

# %%
dvd["visits"].value_counts()
# Out:
# 0    4141
# 1     782
# 2     174
# 3      30
# 4      24
# 7      12
# 6      12
# 5       9
# 8       5
# 9       1
# Name: visits, dtype: int64

# %%
dvd["gender"].value_counts()
# Out:
# female    2702
# male      2488
# Name: gender, dtype: int64

# %%
dvd["age"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       0.19
# 1       0.19
# 2       0.19
# 3       0.19
# 4       0.19
#         ...
# 5185    0.22
# 5186    0.27
# 5187    0.37
# 5188    0.52
# 5189    0.72
# Name: age, Length: 5190, dtype: float64>

# %%
dvd["income"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       0.55
# 1       0.45
# 2       0.90
# 3       0.15
# 4       0.45
#         ...
# 5185    0.55
# 5186    1.30
# 5187    0.25
# 5188    0.65
# 5189    0.25
# Name: income, Length: 5190, dtype: float64>

# %%
a=list(dvd.income)
plt.boxplot(a)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dvd.groupby(['gender','reduced']).mean()
# Out:
# <ipython-input-17-6ce434a34a8a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dvd.groupby(['gender','reduced']).mean()
#                  Unnamed: 0    visits       age    income   illness    health
# gender reduced
# female 0        2524.038512  0.229322  0.465755  0.482735  1.462144  1.115098
#        1        1985.768421  0.400000  0.325684  0.542105  2.242105  1.610526
#        2        1622.618182  0.672727  0.391455  0.560182  2.236364  1.781818
#        3         997.311111  1.333333  0.403111  0.516000  2.733333  1.733333
#        4        1237.740741  0.851852  0.458889  0.466667  2.222222  2.074074
#        5        1169.055556  1.444444  0.401667  0.614444  2.222222  2.500000
#        6        1382.545455  1.363636  0.426364  0.622727  2.363636  1.363636
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(dvd.corr(),cbar=True,annot=True,cmap='viridis')
# Out:
# <ipython-input-103-e096f47d40f0>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dvd.corr(),cbar=True,annot=True,cmap='viridis')
# <Axes: >

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='income', y='visits', data=dvd, color='red')
#plt.xticks(dvd['income'].values)
#plt.yticks(dvd['visits'].values)
#plt.xlabel('income')
#plt.ylabel('Visits')

# %%
sns.histplot(dvd.gender, bins=5, color='red')
# Out:
# <Axes: xlabel='gender', ylabel='Count'>

# %%
gender_counts=dvd['gender'].value_counts()
print(gender_counts)
# Out:
# female    2702
# male      2488
# Name: gender, dtype: int64

# %%
avg_age = dvd['age'].mean()
print("Average Age is :", avg_age * 100)
# Out:
# Average Age is : 40.638535645472054

# %%
sns.histplot(dvd['income'],color='r')
#plt.xlabel('Income')
#plt.ylabel('count')
plt.title('Income')
# Out:
# Text(0.5, 1.0, 'Income')

# %%
illness_counts = dvd['illness'].value_counts()
sns.barplot(x=illness_counts.index, y=illness_counts.values, color='b')
#plt.xlabel('Illness')
#plt.ylabel('Count')
plt.title('Number of Visits by Illness Status')
plt.show()

# %%
sns.scatterplot(x=dvd['age'], y=dvd['income'], color='r')
#plt.xlabel('Age')
#plt.ylabel('Income')
plt.title('Age VS Income')
# Out:
# Text(0.5, 1.0, 'Age VS Income')

# %%
corr_matrix=dvd.corr()
sns.heatmap(corr_matrix,annot=True, color='b')
plt.title("corr matrix")
# Out:
# <ipython-input-86-f437b42cf35e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix=dvd.corr()
# Text(0.5, 1.0, 'corr matrix')

# %%
avg_visits_by_gender=dvd.groupby('gender')['visits'].mean()
print(avg_visits_by_gender)
# Out:
# gender
# female    0.361954
# male      0.236334
# Name: visits, dtype: float64

# %%
max_income_by_illness=dvd.groupby('illness')['income'].max()
print(max_income_by_illness)
# Out:
# illness
# 0    1.5
# 1    1.5
# 2    1.5
# 3    1.5
# 4    1.5
# 5    1.5
# Name: income, dtype: float64

# %%
filtered_data=dvd[dvd['gender']==1]

# %%
sns.boxplot(x=dvd['gender'],y=dvd['income'])
#plt.xlabel('Gender')
#plt.ylabel('Income')
plt.title('income by gender')
# Out:
# Text(0.5, 1.0, 'income by gender')

# %%
bins = [0, 1, 2, 3, 4, 5]  # age groups
age_groups = pd.cut(dvd['age'], bins)
age_group_counts = age_groups.value_counts().sort_index()
sns.barplot(x=age_group_counts.index.astype(str), y=age_group_counts.values, color='r')
#plt.xlabel('Age Group')
#plt.ylabel('Count')
plt.title('Number of Visits by Age Group')
# Out:
# Text(0.5, 1.0, 'Number of Visits by Age Group')

# %%
corr_matrix=dvd.corr()
print(corr_matrix)
# Out:
#             Unnamed: 0    visits       age    income   illness   reduced  \
# Unnamed: 0    1.000000 -0.521645 -0.016322  0.074632 -0.290047 -0.245314
# visits       -0.521645  1.000000  0.124537 -0.076840  0.223552  0.418954
# age          -0.016322  0.124537  1.000000 -0.271073  0.204984  0.094745
# income        0.074632 -0.076840 -0.271073  1.000000 -0.148812 -0.047545
# illness      -0.290047  0.223552  0.204984 -0.148812  1.000000  0.218116
# reduced      -0.245314  0.418954  0.094745 -0.047545  0.218116  1.000000
# health       -0.194966  0.193272  0.018616 -0.085790  0.360110  0.280208
#
#               health
# Unnamed: 0 -0.194966
# visits      0.193272
# age         0.018616
# income     -0.085790
# illness     0.360110
# reduced     0.280208
# health      1.000000
# ...

# %%
sns.heatmap(corr_matrix,annot=True, color='b')
plt.title('corr matrix')
# Out:
# Text(0.5, 1.0, 'corr matrix')

# %%
sns.barplot(x='gender', y='income', data=dvd, color='b')
#plt.xlabel('Gender')
#plt.ylable('Income')
plt.title('Income by Gender')
# Out:
# Text(0.5, 1.0, 'Income by Gender')
